# %% [markdown]
# <a href="https://colab.research.google.com/github/Salma-221/Depi-project/blob/main/Depi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("TrainRidesCleaned.csv",sep=';')
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       08/12/2023         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       16/12/2023         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       19/12/2023         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       20/12/2023         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       27/12/2023         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      01/01/2024
# ...

# %%
df=df.drop_duplicates()

# %%
df["DepartureTime24"]='12:00:00'+df["Departure Time"]
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       08/12/2023         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       16/12/2023         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       19/12/2023         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       20/12/2023         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       27/12/2023         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      01/01/2024
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31653 entries, 0 to 31652
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Transaction ID       31653 non-null  object
#  1   Date of Purchase     31653 non-null  object
#  2   Time of Purchase     31653 non-null  object
#  3   Purchase Type        31653 non-null  object
#  4   Payment Method       31653 non-null  object
#  5   Railcard             10735 non-null  object
#  6   Ticket Class         31653 non-null  object
#  7   Ticket Type          31653 non-null  object
#  8   Price                31653 non-null  int64
#  9   Departure Station    31653 non-null  object
#  10  Arrival Destination  31653 non-null  object
#  11  Date of Journey      31653 non-null  object
#  12  Departure Time       31653 non-null  object
#  13  Arrival Time         31653 non-null  object
#  14  Actual Arrival Time  29773 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID             0
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard               20918
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1880
# Journey Status             0
# Reason for Delay       27481
# Refund Request             0
# DepartureTime24            0
# dtype: int64

# %%
df["Reason for Delay"] = df["Reason for Delay"].fillna("On Time")
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       08/12/2023         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       16/12/2023         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       19/12/2023         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       20/12/2023         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       27/12/2023         18:22:56        Online
#
#   Payment Method Railcard Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      01/01/2024
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID             0
# Date of Purchase           0
# Time of Purchase           0
# Purchase Type              0
# Payment Method             0
# Railcard               20918
# Ticket Class               0
# Ticket Type                0
# Price                      0
# Departure Station          0
# Arrival Destination        0
# Date of Journey            0
# Departure Time             0
# Arrival Time               0
# Actual Arrival Time     1880
# Journey Status             0
# Reason for Delay           0
# Refund Request             0
# DepartureTime24            0
# dtype: int64

# %%
df=df.rename(columns={"Railcard":"Category"})
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       08/12/2023         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       16/12/2023         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       19/12/2023         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       20/12/2023         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       27/12/2023         18:22:56        Online
#
#   Payment Method Category Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      01/01/2024
# ...

# %%
df["Reason for Delay"] = df["Reason for Delay"].fillna("On Time")
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       08/12/2023         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       16/12/2023         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       19/12/2023         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       20/12/2023         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       27/12/2023         18:22:56        Online
#
#   Payment Method Category Ticket Class Ticket Type  Price  \
# 0    Contactless    Adult     Standard     Advance     43
# 1    Credit Card    Adult     Standard     Advance     23
# 2    Credit Card      NaN     Standard     Advance      3
# 3    Credit Card      NaN     Standard     Advance     13
# 4    Contactless      NaN     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      01/01/2024
# ...

# %%
df["Reason for Delay"]=df["Reason for Delay"].str.upper()

# %%
weathercnt=(df["Reason for Delay"] == "WEATHER").sum()
WEATHER_CONDITIONS=(df["Reason for Delay"] == "WEATHER CONDITIONS").sum()
STAFFING=(df["Reason for Delay"] == "STAFFING").sum()
STAFF_SHORTAGE=(df["Reason for Delay"] == "STAFF SHORTAGE").sum()
print(weathercnt)
print(WEATHER_CONDITIONS)
print(STAFFING)
print(STAFF_SHORTAGE)
# Out:
# 995
# 377
# 410
# 399

# %%
df["Reason for Delay"]=df["Reason for Delay"].replace("WEATHER","WEATHER CONDITIONS")
df["Reason for Delay"]=df["Reason for Delay"].replace("STAFF SHORTAGE","STAFFING")

# %%
weathercnt=(df["Reason for Delay"] == "WEATHER").sum()
WEATHER_CONDITIONS=(df["Reason for Delay"] == "WEATHER CONDITIONS").sum()
STAFFING=(df["Reason for Delay"] == "STAFFING").sum()
STAFF_SHORTAGE=(df["Reason for Delay"] == "STAFF SHORTAGE").sum()
print(weathercnt)
print(WEATHER_CONDITIONS)
print(STAFFING)
print(STAFF_SHORTAGE)
# Out:
# 0
# 1372
# 809
# 0

# %%
df["Payment Method"]=df["Payment Method"].str.upper()

# %%
df["Reason for Delay"]=df["Reason for Delay"].replace("CONTACTLESS","ONSITE")

# %%
df["Category"] = df["Category"].fillna("Not Defined")

# %%
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       08/12/2023         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       16/12/2023         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       19/12/2023         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       20/12/2023         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       27/12/2023         18:22:56        Online
#
#   Payment Method     Category Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      01/01/2024
# ...

# %%
df['Date of Purchase'] = pd.to_datetime(df['Date of Purchase'], dayfirst=True, errors='coerce')
df['Date of Journey'] = pd.to_datetime(df['Date of Journey'], dayfirst=True, errors='coerce')
df['Purchase Month'] = df['Date of Purchase'].dt.month_name()
df['Purchase year'] = df['Date of Purchase'].dt.strftime('%Y')
df['Journey year'] = df['Date of Journey'].dt.strftime('%Y')
df['Journey Month'] = df['Date of Journey'].dt.month_name()
df['Journey Day'] = df['Date of Journey'].dt.day_name()
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Category Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
df['Departure Datetime'] = pd.to_datetime(df['Date of Journey'].astype(str) + ' ' + df['Departure Time'])
df['Arrival Datetime'] = pd.to_datetime(df['Date of Journey'].astype(str) + ' ' + df['Arrival Time'])
#df['Journey Duration (min)'] = round((df['Arrival Datetime'] - df['Departure Datetime']).dt.total_seconds()/60,2)
#df.drop("Journey Duration (hr)",axis=1)
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Category Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
df.columns = df.columns.str.strip()
df['Actual Arrival Datetime'] = pd.to_datetime(df['Date of Journey'].astype(str) + ' ' + df['Actual Arrival Time'])
df['Journey Delay (min)'] = ((df['Actual Arrival Datetime'] - df['Arrival Datetime']).dt.total_seconds() / 60)

# %%
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Category Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
df['Transaction ID'][df['Transaction ID'].duplicated()].unique()
# Out:
# array([], dtype=object)

# %%
df[df["Price"]>((df["Price"].mean()))].head()
# Out:
#              Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0   da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 4   2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
# 5   4e1dcd88-3d95-44ef-99fa       2023-12-30         07:56:06        Online
# 8   01df916f-4291-41ec-a37d       2023-12-31         01:43:09       Station
# 18  6b62b452-c491-468d-b39c       2023-12-31         09:12:21        Online
#
#    Payment Method     Category Ticket Class Ticket Type  Price  \
# 0     CONTACTLESS        Adult     Standard     Advance     43
# 4     CONTACTLESS  Not Defined     Standard     Advance     76
# 5     CREDIT CARD  Not Defined     Standard     Advance     35
# 8     CREDIT CARD  Not Defined     Standard     Advance     37
# 18    CREDIT CARD  Not Defined     Standard     Advance     35
#
#         Departure Station    Arrival Destination Date of Journey  \
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df.index, df["Price"])
plt.title("Scatterplot of Price vs Index")
plt.xlabel("Index")
plt.ylabel("Price")
plt.show()

# %%
df.rename(columns={'Category': 'Railcard'}, inplace=True)

# %%
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Railcard Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
print((df["Journey Delay (min)"] < 0).sum())
# Out:
# 0

# %%
'Departure Time' in df.columns
'Arrival Time' in df.columns
'Actual Arrival Time' in df.columns
# Out:
# True

# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # show all columns
pd.set_option('display.width', None)        # don't wrap lines
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Railcard Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
print((df["Journey Delay (min)"] < 0).sum())
# Out:
# 0

# %%
#df['Journey Duration (min)c']=df['Journey Duration (min)']
#df['Journey Delay (min)c']=df['Journey Delay (min)']
#df.drop('Journey Duration (min)', axis=1, inplace=True)
#df.drop('Journey Delay (min)', axis=1, inplace=True)
#df.head()
#df["Journey Delay (min)"].dtype

# %%
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Railcard Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
import numpy as np
df["Price Bins"] = np.select(
    [
        (df["Price"] < 20),
        (df["Price"] >= 20) & (df["Price"] < 40),
        (df["Price"] >= 40) & (df["Price"] < 60),
        (df["Price"] >= 60) & (df["Price"] < 80),
        (df["Price"] >= 80) & (df["Price"] < 100),
        (df["Price"] >= 100) & (df["Price"] < 120),
        (df["Price"] >= 120) & (df["Price"] < 140),
        (df["Price"] >= 140) & (df["Price"] < 160),
        (df["Price"] >= 160) & (df["Price"] < 180),
        (df["Price"] >= 180) & (df["Price"] < 200),
        (df["Price"] >= 200) & (df["Price"] < 220),
        (df["Price"] >= 220) & (df["Price"] < 240),
        (df["Price"] >= 240) & (df["Price"] < 260),
        (df["Price"] >= 260) & (df["Price"] <= 280)
    ],
    [
        "Below 20", "20-39", "40-59", "60-79", "80-99",
        "100-119", "120-139", "140-159", "160-179",
        "180-199", "200-219", "220-239", "240-259", "260-280"
    ],
    default="Above 280"
)

# %%
# Out:
#             Transaction ID Date of Purchase Time of Purchase Purchase Type  \
# 0  da8a6ba8-b3dc-4677-b176       2023-12-08         12:41:11        Online
# 1  b0cdd1b0-f214-4197-be53       2023-12-16         11:23:01       Station
# 2  f3ba7a96-f713-40d9-9629       2023-12-19         19:51:27        Online
# 3  b2471f11-4fe7-4c87-8ab4       2023-12-20         23:00:36       Station
# 4  2be00b45-0762-485e-a7a3       2023-12-27         18:22:56        Online
#
#   Payment Method     Railcard Ticket Class Ticket Type  Price  \
# 0    CONTACTLESS        Adult     Standard     Advance     43
# 1    CREDIT CARD        Adult     Standard     Advance     23
# 2    CREDIT CARD  Not Defined     Standard     Advance      3
# 3    CREDIT CARD  Not Defined     Standard     Advance     13
# 4    CONTACTLESS  Not Defined     Standard     Advance     76
#
#        Departure Station    Arrival Destination Date of Journey  \
# 0      London Paddington  Liverpool Lime Street      2024-01-01
# ...

# %%
df.to_csv("TrainRides_Cleaned_Enhanced2.csv", index=False)
